# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /opt/anaconda3/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.8/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->bs4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import required module
import requests
import time
from bs4 import BeautifulSoup
import urllib

# %%
#web URL

url = "https://www.justice.gov/eoir/eoir-policy-manual"
#get URL content

response = requests.get(url,verify=False)
#print(response.text)
html = response.text

#parse HTML Code
soup = BeautifulSoup(html,'html.parser')
#print(soup)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="no-js ie iem7 not-responsive" lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="no-js ie lt-ie9 lt-ie8 lt-ie7 not-responsive" lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="no-js ie lt-ie9 lt-ie8 not-responsive" lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="no-js ie lt-ie9 not-responsive" lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><html class="no-js ie responsive" lang="en" dir="ltr" prefix=": og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><![endif]-->
# <!--[if !IE]><!-->
# <html class="no-js responsive" dir="ltr" lang="en" prefix=": og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
#  <!--<![endif]-->
#  <head>
#   <title>
#    EOIR Policy Manual | EOIR | Department of Justice
#   </title>
#   <!--[if IE]><![endif]-->
#   <meta charset="utf-8"/>
#   <script src="/sites/all/themes/justice/js/uswds-init.min.js">
#   </script>
#   <link href="/eoir/eoir-policy-manual/directorletter" rel="next"/>
#   <script async="async" id="_fed_an_ua_tag" src="https://dap.digitalgov.gov/Universal-Federated-Analytics-Min.js?agency=DOJ&amp;sp=find&amp;yt=true&amp;subagency=eoir">
#   </script>
#   <link href="https://www.justice.gov/sites/default/files/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="http://www.w3.org/1999/xhtml/vocab" rel="profile"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <link href="https://www.justice.gov/sites/all/themes/justice/apple-touch-icon-precomposed-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="https://www.justice.gov/sites/all/themes/justice/apple-touch-icon-precomposed-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="https://www.justice.gov/sites/all/themes/justice/apple-touch-icon-precomposed-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="https://www.justice.gov/sites/all/themes/justice/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed"/>
#   <script type="application/ld+json">
#    {"@context":"http:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"Executive Office for Immigration Review","@id":"https:\/\/www.justice.gov\/eoir"}}]}
#   </script>
#   <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.justice.gov/eoir/eoir-policy-manual" rel="canonical"/>
#   <meta content="article" property="og:type"/>
#   <meta content="EOIR Policy Manual" property="og:title"/>
#   <meta content="2020-11-16T14:28:25-05:00" property="article:published_time"/>
#   <meta content="2021-03-24T19:32:36-04:00" property="article:modified_time"/>
#   <link href="https://www.justice.gov/sites/default/files/advagg_css/css__GoAI2EszLp9GWgdJrekSmMOQIzT-Ja7jnEz0vBWkj9U__4kc6UcpASm6HOy-wzjgKaqDqOyi8OzkZXdxCJFiJ4_k___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 8]>
# <link type="text/css" rel="stylesheet" href="https://www.justice.gov/sites/default/files/advagg_css/css__JQfwsVb8AHjJsxvkLORr8MKWY6kpVUNsHSIlUeHBziE__93cIHWlo-aXRk_10y3dT20ycGlc9wpZMjbiGRGMO44c___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.css" media="all" />
# <![endif]-->
#  </head>
#  <body class="html not-front not-logged-in page-node page-node- page-node-1400476 node-type-book og-context og-context-node og-context-node-1644 i18n-en section-eoir og-context-executive-office-for-immigration-review section-eoir one-sidebar sidebar-first og-context-executive-office-for-immigration-review" x-ms-format-detection="none">
#   <a class="element-invisible element-focusable" href="#main-content" id="skip-link">
#    Skip to main content
#   </a>
#   <section aria-label="Official government website" class="usa-banner">
#    <div class="usa-accordion">
#     <header class="usa-banner__header">
#      <div class="usa-banner__inner">
#       <div class="grid-col-auto">
#        <img alt="U.S. flag" class="usa-banner__header-flag" src="/sites/all/themes/justice/images/us_flag_small.png"/>
#       </div>
#       <div class="grid-col-fill tablet:grid-col-auto">
#        <p class="usa-banner__header-text">
#         An official website of the United States government
#        </p>
#        <p aria-hidden="true" class="usa-banner__header-action">
#         Here’s how you know
#        </p>
#       </div>
#       <button aria-controls="gov-banner" aria-expanded="false" class="usa-accordion__button usa-banner__button">
#        <span class="usa-banner__button-text">
#         Here’s how you know
#        </span>
#       </button>
#      </div>
#     </header>
#     <div class="usa-banner__content usa-accordion__content" id="gov-banner">
#      <div class="grid-row grid-gap-lg">
#       <div class="usa-banner__guidance tablet:grid-col-6">
#        <img alt="Dot gov" class="usa-banner__icon usa-media-block__img" role="img" src="/sites/all/themes/justice/images/icon-dot-gov.svg"/>
#        <div class="usa-media-block__body">
#         <p>
#          <strong>
#           Official websites use .gov
#          </strong>
#          <br/>
#          A
#          <strong>
#           .gov
#          </strong>
#          website belongs to an official government organization in the United States.
#         </p>
#        </div>
#       </div>
#       <div class="usa-banner__guidance tablet:grid-col-6">
#        <img alt="Https" class="usa-banner__icon usa-media-block__img" role="img" src="/sites/all/themes/justice/images/icon-https.svg"/>
#        <div class="usa-media-block__body">
#         <p>
#          <strong>
#           Secure .gov websites use HTTPS
#          </strong>
#          <br/>
#          A
#          <strong>
#           lock
#          </strong>
#          (
#          <span class="icon-lock">
#           <svg aria-labelledby="banner-lock-title banner-lock-description" class="usa-banner__lock-image" height="64" role="img" viewbox="0 0 52 64" width="52" xmlns="http://www.w3.org/2000/svg">
#            <title id="banner-lock-title">
#             Lock
#            </title>
#            <desc id="banner-lock-description">
#             A locked padlock
#            </desc>
#            <path d="M26 0c10.493 0 19 8.507 19 19v9h3a4 4 0 0 1 4 4v28a4 4 0 0 1-4 4H4a4 4 0 0 1-4-4V32a4 4 0 0 1 4-4h3v-9C7 8.507 15.507 0 26 0zm0 8c-5.979 0-10.843 4.77-10.996 10.712L15 19v9h22v-9c0-6.075-4.925-11-11-11z" fill="#000000" fill-rule="evenodd">
#            </path>
#           </svg>
#          </span>
#          ) or
#          <strong>
#           https://
#          </strong>
#          means you’ve safely connected to the .gov website. Share sensitive information only on official, secure websites.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section aria-label="Navigation menu" class="justice-mobile-menu-container">
#    <a class="site-branding__logo mobile" href="/" rel="home" title="The United States Department of Justice">
#     <img alt="The United States Department of Justice" src="https://www.justice.gov/sites/default/files/header-logo-mobile_bronze5.png"/>
#    </a>
#    <div class="justice-mobile-mean-container">
#    </div>
#   </section>
#   <section aria-label="Main section" class="l-page not-panelized not-panelized">
#    <a name="page-top">
#    </a>
#    <div class="l-header-wrapper">
#     <header class="l-header" role="banner">
#      <div class="l-branding site-branding">
#       <a class="site-branding__logo desktop" href="/" rel="home" title="The United States Department of Justice">
#        <img alt="The United States Department of Justice" src="https://www.justice.gov/sites/default/files/header-logo_bronze-resized-5-2.png"/>
#       </a>
#      </div>
#      <div class="l-region l-region--header">
#       <div class="block block--usasearch-hosted block--usasearch-hosted-form block--usasearch-hosted-form" id="block-usasearch-hosted-form">
#        <div class="block__content block__content">
#         <form accept-charset="UTF-8" action="https://search.justice.gov/search" class="usasearch-hosted-box" id="usasearch-hosted-box" method="get">
#          <div>
#           <div class="container-inline">
#            <h2 class="element-invisible">
#             Search form
#            </h2>
#            <div class="form-item form-type-textfield form-item-usasearch-hosted-box">
#             <label class="element-invisible" for="edit-usasearch-hosted-box--2">
#              Search
#             </label>
#             <input aria-label="Search this site" autocomplete="off" class="usagov-search-autocomplete ui-autocomplete-input ui-corner-all form-text" id="edit-usasearch-hosted-box--2" maxlength="128" name="query" placeholder="Search this site" size="15" type="text" value=""/>
#            </div>
#            <div class="form-actions form-wrapper" id="edit-actions">
#             <input class="form-submit" id="edit-submit" name="op" type="submit" value="Search"/>
#            </div>
#            <input name="affiliate" type="hidden" value="justice"/>
#           </div>
#          </div>
#         </form>
#        </div>
#       </div>
#      </div>
#     </header>
#     <section aria-label="Navigation">
#      <div class="l-region l-region--navigation">
#       <div class="block block--nice-menus block--nice-menus-1 block--nice-menus-1" id="block-nice-menus-1">
#        <h2 class="block__title block__title">
#         <span class="nice-menu-hide-title">
#          Main menu
#         </span>
#        </h2>
#        <div class="block__content block__content">
#         <ul class="nice-menu nice-menu-down nice-menu-main-menu" id="nice-menu-1">
#          <li class="menu-1259 menuparent menu-path-node-82626 first odd">
#           <a href="/about" title="">
#            About
#           </a>
#           <ul>
#            <li class="menu-1267 menu-path-node-82606 first odd">
#             <a href="/doj/budget-and-performance" title="">
#              Budget &amp; Performance
#             </a>
#            </li>
#            <li class="menu-51706 menu-path-node-1206021 even">
#             <a href="/history" title="">
#              History
#             </a>
#            </li>
#            <li class="menu-89781 menu-path-node-1666 odd last">
#             <a href="/opcl">
#              Privacy Program
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-1260 menuparent menu-path-node-33666-chart even">
#           <a href="/agencies/chart" title="">
#            Our Agency
#           </a>
#           <ul>
#            <li class="menu-9686 menu-path-node-1652 first odd">
#             <a href="/ag" title="">
#              The Attorney General
#             </a>
#            </li>
#            <li class="menu-90596 menu-path-node-33666-chart even">
#             <a href="/agencies/chart" title="">
#              Organizational Chart
#             </a>
#            </li>
#            <li class="menu-90591 menu-path-node-924706 odd last">
#             <a href="/agencies/alphabetical-listing-components-programs-initiatives" title="">
#              Alphabetical Listing
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-107586 menu-path-node-1105656 odd">
#           <a href="/topics" title="">
#            Topics
#           </a>
#          </li>
#          <li class="menu-1263 menuparent menu-path-node-780336 even">
#           <a href="/news" title="">
#            News
#           </a>
#           <ul>
#            <li class="menu-1279 menu-path-node-665661 first odd">
#             <a href="/videos" title="">
#              Videos
#             </a>
#            </li>
#            <li class="menu-1280 menu-path-opa-galleries even">
#             <a href="/opa/galleries" title="">
#              Photos
#             </a>
#            </li>
#            <li class="menu-107921 menu-path-node-828151 odd">
#             <a href="/blogs" title="">
#              Blogs
#             </a>
#            </li>
#            <li class="menu-118511 menu-path-node-1222781 even last">
#             <a href="/podcasts" title="">
#              Podcasts
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-1262 menuparent menu-path-node-82271 active-trail odd">
#           <a href="/resources" title="">
#            Resources
#           </a>
#           <ul>
#            <li class="menu-116071 menu-path-node-1270461 active-trail first odd">
#             <a class="active" href="/guidance" title="">
#              Guidance Documents
#             </a>
#            </li>
#            <li class="menu-120886 menu-path-node-1407871 even">
#             <a href="/grants" title="">
#              Grants
#             </a>
#            </li>
#            <li class="menu-1272 menu-path-justicegov-forms odd">
#             <a href="http://www.justice.gov/forms" title="">
#              Forms
#             </a>
#            </li>
#            <li class="menu-1273 menu-path-node-643761 even">
#             <a href="/publications" title="">
#              Publications
#             </a>
#            </li>
#            <li class="menu-5306 menu-path-largecases odd">
#             <a href="/largecases" title="">
#              Information for Victims in Large Cases
#             </a>
#            </li>
#            <li class="menu-94896 menu-path-node-322336 even last">
#             <a href="/jm/justice-manual">
#              Justice Manual
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-92596 menuparent menu-path-node-865991 even">
#           <a href="/careers" title="">
#            Careers
#           </a>
#           <ul>
#            <li class="menu-2925 menu-path-node-3643 first odd">
#             <a href="/legal-careers">
#              Legal Careers
#             </a>
#            </li>
#            <li class="menu-3650 menu-path-node-796646 even">
#             <a href="/careers/veteran-recruitment" title="">
#              Veteran Recruitment
#             </a>
#            </li>
#            <li class="menu-92601 menu-path-node-6001 odd last">
#             <a href="/careers/disability-hiring" title="">
#              Disability Hiring
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="menu-1265 menu-path-node-82636 odd last">
#           <a href="/contact-us" title="">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#    <div class="l-lower">
#     <div class="l-main-wrapper">
#      <div class="l-main">
#       <section aria-label="Breadcrumb" class="site-info">
#        <h2 class="element-invisible">
#         You are here
#        </h2>
#        <div class="breadcrumb">
#         <a href="/front">
#          Home
#         </a>
#         »
#         <a href="/eoir">
#          Executive Office for Immigration Review
#         </a>
#        </div>
#       </section>
#       <section aria-label="Preliminary content" class="pre-content clearfix">
#        <div class="l-region l-region--pre-content">
#         <div class="block block--doj-sharing block--doj-sharing-doj-sharing block--doj-sharing-doj-sharing" id="block-doj-sharing-doj-sharing">
#          <div class="block__content block__content">
#           <div class="doj-sharing" style="display:none;">
#            <a id="doj-sharing-toggle" tabindex="0" title="Choose a social sharing platform">
#             Share
#            </a>
#            <ul>
#             <li>
#              <a data-event-label="Share on Facebook" href="http://www.facebook.com/sharer/sharer.php?u=https://www.justice.gov/eoir/eoir-policy-manual" target="_blank" title="Share on Facebook">
#               Facebook
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Share on Twitter" href="http://twitter.com/intent/tweet?url=https://www.justice.gov/eoir/eoir-policy-manual&amp;text=EOIR%20Policy%20Manual" target="_blank" title="Share on Twitter">
#               Twitter
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Share on LinkedIn" href="http://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.justice.gov/eoir/eoir-policy-manual&amp;title=EOIR%20Policy%20Manual" target="_blank" title="Share on LinkedIn">
#               LinkedIn
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Share on Digg" href="http://digg.com/submit?url=https://www.justice.gov/eoir/eoir-policy-manual&amp;title=EOIR%20Policy%20Manual" target="_blank" title="Share on Digg">
#               Digg
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Share on Reddit" href="http://reddit.com/submit?url=https://www.justice.gov/eoir/eoir-policy-manual&amp;title=EOIR%20Policy%20Manual" target="_blank" title="Share on Reddit">
#               Reddit
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Share on Pinterest" href="http://pinterest.com/pin/create/button/?url=https://www.justice.gov/eoir/eoir-policy-manual&amp;media=https%3A//www.justice.gov/sites/all/modules/features/doj_sharing/images/doj-seal-pin.png&amp;title=EOIR%20Policy%20Manual" target="_blank" title="Share on Pinterest">
#               Pinterest
#              </a>
#             </li>
#             <li>
#              <a data-event-label="Email" href="mailto:?body=https://www.justice.gov/eoir/eoir-policy-manual&amp;subject=EOIR%20Policy%20Manual" title="Email">
#               Email
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </section>
#       <aside class="l-region l-region--sidebar-first">
#        <div class="block block--book block--book-navigation block--book-navigation" id="block-book-navigation" role="navigation">
#         <h2 class="block__title block__title">
#          <a class="book-title active" href="/eoir/eoir-policy-manual">
#           EOIR Policy Manual
#          </a>
#         </h2>
#         <div class="block__content block__content">
#          <ul class="menu">
#           <li class="first leaf">
#            <a href="/eoir/eoir-policy-manual/directorletter">
#             Letter from the EOIR Director
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/eoir/eoir-policy-manual/main">
#             Seal
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/eoir/eoir-policy-manual/i/EOIRleadership">
#             EOIR Leadership
#            </a>
#           </li>
#           <li class="collapsed">
#            <a href="/eoir/eoir-policy-manual/part-i-introduction">
#             Part I - Introduction
#            </a>
#           </li>
#           <li class="collapsed">
#            <a href="/eoir/eoir-policy-manual/part-ii-ocij-practice-manual">
#             Part II - OCIJ Practice Manual
#            </a>
#           </li>
#           <li class="collapsed">
#            <a href="/eoir/eoir-policy-manual/iii">
#             Part III - BIA Practice Manual
#            </a>
#           </li>
#           <li class="collapsed">
#            <a href="/eoir/eoir-policy-manual/part-iv-ocaho-practice-manual">
#             Part IV - OCAHO Practice Manual
#            </a>
#           </li>
#           <li class="collapsed">
#            <a href="/eoir/eoir-policy-manual/part-v-miscellaneous">
#             Part V - Miscellaneous
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/eoir/eoir-policy-manual/vi">
#             Part VI - Operating Policies and Procedures Memoranda
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/eoir/eoir-policy-manual/vii">
#             Part VII - Memoranda
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/eoir/eoir-policy-manual/viii">
#             Part VIII - Uniform Docketing System Manual
#            </a>
#           </li>
#           <li class="last collapsed">
#            <a href="/eoir/eoir-policy-manual/VIIII">
#             Appendices
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </aside>
#       <div class="l-content" role="main">
#        <a id="main-content" tabindex="-1">
#        </a>
#        <h1>
#         EOIR Policy Manual
#        </h1>
#        <article about="/eoir/eoir-policy-manual" class="node node--book node--full node--book--full" typeof="sioc:Item foaf:Document">
#         <header>
#          <span class="rdf-meta element-hidden" content="EOIR Policy Manual" property="dc:title">
#          </span>
#         </header>
#         <div class="node__content">
#          <div class="field field--name-field-book-body field--type-text-long field--label-hidden">
#           <div class="field__items">
#            <div class="field__item even">
#             <p>
#              <strong>
#               Search the EOIR Policy Manual
#              </strong>
#             </p>
#             <form action="https://search.justice.gov/search" method="get" target="_blank">
#              <input name="query" placeholder="Search..." type="text"/>
#              <input name="op" type="submit" value="Search"/>
#              <input name="affiliate" type="hidden" value="eoir-policy-manual"/>
#             </form>
#             <hr/>
#             <p>
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="book-navigation" id="book-navigation-1400476">
#           <ul class="menu">
#            <li class="first leaf">
#             <a href="/eoir/eoir-policy-manual/directorletter">
#              Letter from the EOIR Director
#             </a>
#            </li>
#            <li class="leaf">
#             <a href="/eoir/eoir-policy-manual/main">
#              Seal
#             </a>
#            </li>
#            <li class="leaf">
#             <a href="/eoir/eoir-policy-manual/i/EOIRleadership">
#              EOIR Leadership
#             </a>
#            </li>
#            <li class="collapsed">
#             <a href="/eoir/eoir-policy-manual/part-i-introduction">
#              Part I - Introduction
#             </a>
#            </li>
#            <li class="collapsed">
#             <a href="/eoir/eoir-policy-manual/part-ii-ocij-practice-manual">
#              Part II - OCIJ Practice Manual
#             </a>
#            </li>
#            <li class="collapsed">
#             <a href="/eoir/eoir-policy-manual/iii">
#              Part III - BIA Practice Manual
#             </a>
#            </li>
#            <li class="collapsed">
#             <a href="/eoir/eoir-policy-manual/part-iv-ocaho-practice-manual">
#              Part IV - OCAHO Practice Manual
#             </a>
#            </li>
#            <li class="collapsed">
#             <a href="/eoir/eoir-policy-manual/part-v-miscellaneous">
#              Part V - Miscellaneous
#             </a>
#            </li>
#            <li class="leaf">
#             <a href="/eoir/eoir-policy-manual/vi">
#              Part VI - Operating Policies and Procedures Memoranda
#             </a>
#            </li>
#            <li class="leaf">
#             <a href="/eoir/eoir-policy-manual/vii">
#              Part VII - Memoranda
#             </a>
#            </li>
#            <li class="leaf">
#             <a href="/eoir/eoir-policy-manual/viii">
#              Part VIII - Uniform Docketing System Manual
#             </a>
#            </li>
#            <li class="last collapsed">
#             <a href="/eoir/eoir-policy-manual/VIIII">
#              Appendices
#             </a>
#            </li>
#           </ul>
#           <div class="book-navigation__links">
#            <a class="book-navigation__next" href="/eoir/eoir-policy-manual/directorletter" title="Go to next page">
#             Letter from the EOIR Director ›
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="node__updated">
#          Updated March 24, 2021
#         </div>
#        </article>
#       </div>
#      </div>
#      <!-- /.l-main -->
#     </div>
#     <!-- /.l-main-wrapper -->
#    </div>
#    <!-- /.l-lower -->
#    <div class="l-footer-wrapper">
#     <footer class="l-footer" role="contentinfo">
#      <div class="l-region l-region--footer">
#       <nav class="block block--menu block--menu-menu-footer-menu-justice block--menu-menu-footer-menu-justice" id="block-menu-menu-footer-menu-justice" role="navigation">
#        <h2 class="block__title block__title">
#         Footer Menu Justice
#        </h2>
#        <ul class="menu">
#         <li class="first expanded">
#          <span class="nolink" title="">
#           First Column
#          </span>
#          <ul class="menu">
#           <li class="first leaf">
#            <a href="/espanol" title="">
#             en ESPAÑOL
#            </a>
#           </li>
#           <li class="last leaf">
#            <a href="/contact-us" title="">
#             Contact DOJ
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="expanded">
#          <span class="nolink" title="">
#           Second Column
#          </span>
#          <ul class="menu">
#           <li class="first leaf">
#            <a href="/archives/doj-archive" title="">
#             Archive
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/accessibility/accessibility-information" title="">
#             Accessibility
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/information-quality" title="">
#             Information Quality
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/doj/privacy-policy" title="">
#             Privacy Policy
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/legalpolicies" title="">
#             Legal Policies &amp; Disclaimers
#            </a>
#           </li>
#           <li class="last leaf">
#            <a href="/social" title="">
#             Social Media
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="last expanded">
#          <span class="nolink" title="">
#           Third Column
#          </span>
#          <ul class="menu">
#           <li class="first leaf">
#            <a href="/doj/budget-and-performance" title="">
#             Budget &amp; Performance
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="https://oig.justice.gov/" title="">
#             Office of the Inspector General
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/jmd/eeo-program-status-report" title="">
#             No FEAR Act
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/employees" title="">
#             For Employees
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="/oip" title="">
#             FOIA
#            </a>
#           </li>
#           <li class="leaf">
#            <a href="https://usa.gov" title="">
#             USA.gov
#            </a>
#           </li>
#           <li class="last leaf">
#            <a href="https://www.vote.gov" title="">
#             Vote.gov
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </nav>
#       <div class="block block--doj-theme-justice block--doj-theme-justice-footer-address-justice block--doj-theme-justice-footer-address-justice" id="block-doj-theme-justice-footer-address-justice">
#        <div class="block__content block__content">
#         <div class="address">
#          <h2>
#           U.S. Department of Justice
#          </h2>
#          950 Pennsylvania Avenue, NW
#          <br/>
#          Washington, DC 20530-0001
#         </div>
#        </div>
#       </div>
#       <div class="block block--follow block--follow-site block--follow-site" id="block-follow-site">
#        <h2 class="block__title block__title">
#         Stay Connected with Justice:
#        </h2>
#        <div class="block__content block__content">
#         <div class="follow-links clearfix site">
#          <span class="follow-link-wrapper follow-link-wrapper-instagram">
#           <a class="follow-link follow-link-instagram follow-link-site" href="https://www.instagram.com/thejusticedept/" title="Follow us on Instagram">
#            Instagram
#           </a>
#          </span>
#          <span class="follow-link-wrapper follow-link-wrapper-facebook">
#           <a class="follow-link follow-link-facebook follow-link-site" href="http://www.facebook.com/DOJ" title="Follow us on Facebook">
#            Facebook
#           </a>
#          </span>
#          <span class="follow-link-wrapper follow-link-wrapper-twitter">
#           <a class="follow-link follow-link-twitter follow-link-site" href="http://www.twitter.com/TheJusticeDept" title="Follow us on Twitter">
#            Twitter
#           </a>
#          </span>
#          <span class="follow-link-wrapper follow-link-wrapper-youtube">
#           <a class="follow-link follow-link-youtube follow-link-site" href="http://www.youtube.com/TheJusticeDepartment" title="Follow us on YouTube">
#            YouTube
#           </a>
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="block block--doj-theme-justice block--doj-theme-justice-footer-govdelivery-link block--doj-theme-justice-footer-govdelivery-link" id="block-doj-theme-justice-footer-govdelivery-link">
#        <div class="block__content block__content">
#         <div class="update-title">
#          <div class="title">
#           <h2>
#            <a href="https://public.govdelivery.com/accounts/USDOJ/subscriber/new">
#             Email Updates
#            </a>
#           </h2>
#          </div>
#          <div class="email-logo">
#           <a href="https://public.govdelivery.com/accounts/USDOJ/subscriber/new">
#            <img alt="Email icon" src="/sites/all/themes/justice/images/email-icon.png" title="Follow us on Email"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </section>
#   <!--[if (gte IE 6)&(lte IE 8)]>
# <script type="text/javascript" src="https://www.justice.gov/sites/default/files/advagg_js/js__DX31ni-5_e6szwXM9n1RjbVYGWtWQoR6-QflQsrHl2A__3lrek2htCtPxZjqpIb3dz3oQpFcPiveRsXFLoH7Vkl4___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js"></script>
# <![endif]-->
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.7/jquery.min.js'>\x3C/script>")
# //--><!]]>
#   </script>
#   <script src="https://www.justice.gov/sites/default/files/advagg_js/js__6RA4S5to--opubrbto2MmAz0OReVIOPHZPjxx2So3gk__uyJXRuqSWxe4qoVvWb1r2AB6F2uG3dNYPfSpGyHUZYo___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js" type="text/javascript">
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# window.jQuery.ui || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/ui/ui/minified/jquery-ui.min.js'>\x3C/script>")
# //--><!]]>
#   </script>
#   <script src="https://www.justice.gov/sites/default/files/advagg_js/js__0V8Yun-U989j1FtsyegMSBhq9uqsgNE4UenZ0SZ6MyQ__R2potmfWLI_iKxPdFhZi_86f6fPCSP7QUjpUtB2Xkds___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js" type="text/javascript">
#   </script>
#   <!--[if (gte IE 6)&(lte IE 8)]>
# <script type="text/javascript" src="https://www.justice.gov/sites/default/files/advagg_js/js__Is0t3S6uG-xQ8ys7YnU6WeAtd702ckZ-Wi9OWJRauyI__Jdm3LrCpGF1KSCQ_ESXxT3RzbevG63UK3o76ja1ys2A___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js"></script>
# <![endif]-->
#   <script src="https://www.justice.gov/sites/default/files/advagg_js/js__yhYAXcVSQedJfYda5f4DYaocitbbaNyF-8L_RI5sjyU__o2afeIuvrNfhpTdVwxKsRYOsZsLwZhQYcJKGxnkm9Bw___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","autocomplete_limit":{"limit":2},"colorbox":{"transition":"none","speed":"350","opacity":"0.85","slideshow":true,"slideshowAuto":true,"slideshowSpeed":"6000","slideshowStart":"start slideshow","slideshowStop":"stop slideshow","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","overlayClose":true,"returnFocus":true,"maxWidth":"98%","maxHeight":"98%","initialWidth":"300","initialHeight":"500","fixed":true,"scrolling":true,"mobiledetect":false,"mobiledevicewidth":"480px"},"nice_menus_options":{"delay":"800","speed":"fast"},"mediaelementAll":true,"better_exposed_filters":{"views":{"doj_banner":{"displays":{"block":{"filters":[]}}},"og_sidebar":{"displays":{"block":{"filters":[]}}}}},"responsive_menus":[{"selectors":".responsive .block--nice-menus .block__content, .responsive .l-region--navigation .block__content","container":".justice-mobile-mean-container","trigger_txt":"\u003Cspan \/\u003E\u003Cspan \/\u003E\u003Cspan \/\u003E","close_txt":"X","close_size":"18px","position":"right","media_size":"704","show_children":"1","expand_children":"1","expand_txt":"+","contract_txt":"-","remove_attrs":"1","responsive_menus_style":"mean_menu"}],"tablesorter":{"zebra":1,"odd":"odd","even":"even"},"extlink":{"extTarget":0,"extClass":"ext","extLabel":"(link is external)","extImgClass":0,"extIconPlacement":0,"extSubdomains":1,"extExclude":"\\.(gov|mil|fed\\.us)(\\\/.*)?$","extInclude":"","extCssExclude":"","extCssExplicit":"","extAlert":"_blank","extAlertText":{"value":"The Department of Justice does not endorse the organizations or views represented by this site and takes no responsibility for, and exercises no control over, the accuracy, accessibility, copyright or trademark compliance or legality of the material contained on this site.\n\nThank you for visiting our site.","format":"full_html"},"mailtoClass":"mailto","mailtoLabel":"(link sends e-mail)"},"extlink_extra":{"extlink_alert_type":"colorbox","extlink_alert_type_colorbox_mobile":"confirm","extlink_alert_text_colorbox_mobile":"You are now leaving a Department of Justice Web site. You are about to access:\n\n[extlink:external-url]\n\nThe Department of Justice does not endorse the organizations or views represented by this site and takes no responsibility for, and exercises no control over, the accuracy, accessibility, copyright or trademark compliance or legality of the material contained on this site.\n\nThank you for visiting our site.","extlink_alert_timer":"4","extlink_alert_url":"\/now-leaving?js=1","extlink_cache_fix":1,"extlink_exclude_warning":"\\.(ns2cloud\\.com)(\\\/.*)?$","extlink_508_fix":1,"extlink_508_text":" [external link]","extlink_url_override":0,"extlink_url_params":{"external_url":null,"back_url":null}},"urlIsAjaxTrusted":{"https:\/\/search.justice.gov\/search":true},"ogContext":{"groupType":"node","gid":"1644"},"ajaxPageState":{"js":{"sites\/all\/themes\/justice\/libraries\/html5shiv\/html5shiv.min.js":1,"sites\/all\/themes\/justice\/libraries\/html5shiv\/html5shiv-printshiv.min.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jquery\/1.7.2\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/themes\/contrib\/omega\/omega\/js\/no-js.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jqueryui\/1.10.2\/jquery-ui.min.js":1,"sites\/all\/themes\/justice\/js\/justice.early-behaviors.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/jquery.bgiframe.js":1,"sites\/all\/libraries\/jquery.hoverIntent\/jquery.hoverIntent.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/superfish.js":1,"sites\/all\/modules\/contrib\/nice_menus\/js\/nice_menus.js":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelement-and-player.min.js":1,"misc\/form.js":1,"sites\/all\/modules\/contrib\/tablesorte ...
# //--><!]]>
#   </script>
#   <script src="https://www.justice.gov/sites/default/files/advagg_js/js__7By10u7uYYvSywdJUkrylttXj14EhgtaUf3-fDA8IhE__HBrQCUVyCkCJhNWkn6mDS0Ab3sRSYIiAVZlOlGbTrQw___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# var usasearch_config={siteHandle:'justice'};
# //--><!]]>
#   </script>
#   <script src="https://www.justice.gov/sites/default/files/advagg_js/js__s1-mnVjt_wWz2DE2RHXFGav8iMqiA2qBHM_o-rYl6wk__hFXOJ6G_cAX35gQlNMqNou2vYOQ7S8ZcL63noNIO9ZA___nrWRzhBBHDvouD4BrFFlNgm--gn8ZgP1Ems9pO3XkI.js" type="text/javascript">
#   </script>
#  </body>
# </html>
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
url = "https://www.justice.gov/eoir/eoir-policy-manual/part-ii-ocij-practice-manual"

# %%
#first parse table of contents page -- can we scrape everything from this page?
rows = soup.find_all('div',attrs={'class':'book-navigation'})

# print(toc.prettify())
toc=[]
for row in rows:
#     print(row.text)
    columns=row.find_all('a')
    for index,column in enumerate(columns):
#         print(index,column.text)
        if(index<15):
            toc.append(column.text)
        
print(toc)
# Out:
# ['Introductory Information', 'Chapter 1 - The Immigration Court', 'Chapter 2 - Appearances Before the Immigration Court', 'Chapter 3 - Filing with the Immigration Court', 'Chapter 4 - Hearings Before the Immigration Judges', 'Chapter 5 - Motions before the Immigration Court', 'Chapter 6 - Appeals of Immigration Judge Decisions ', 'Chapter 7 - Other  Proceedings before Immigration Judges', 'Chapter 8 - Stays', 'Chapter 9 - Detention and Bond', 'Chapter 10 - Discipline of Practitioners', 'Chapter 11 - Forms', 'Chapter 12 - Freedom of Information Act (FOIA)', 'Chapter 13 - Public Input', 'Chapter 14 - Local Operating Procedures']

# %%
#trying to scrape Chapter 1: headings and content in the link

one=[]
page=1

while page<15:
    response = requests.get(url,verify=False)
    html = response.text
    soup = BeautifulSoup(html,'html.parser')
    url = "https://www.justice.gov/eoir/eoir-policy-manual/" + str(page)  
    rows = soup.find_all('div',attrs={'class':'book-navigation'})
    for row in rows:
#     print(row.text)
        columns=row.find_all('a')
        for index,column in enumerate(columns):
            print(index,column.text)
#             if(index==0):
#                 one.append(column.text)
    page=page+1
    time.sleep(1)
# print(one)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 1.1 - Scope of Part II: The Office of the Chief Immigration Judge
# 1 1.2 - Function of the Office of the Chief Immigration Judge
# 2 1.3 - Composition of the Office of the Chief Immigration Judge
# 3  1.4 - Jurisdiction and Authority
# 4 1.5 - Public Access
# 5 1.6 - Inquiries
# 6 ‹ Introductory Information
# 7 up
# 8 1.1 - Scope of Part II: The Office of the Chief Immigration Judge ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 1.1 - Scope of Part II: The Office of the Chief Immigration Judge
# 1 1.2 - Function of the Office of the Chief Immigration Judge
# 2 1.3 - Composition of the Office of the Chief Immigration Judge
# 3  1.4 - Jurisdiction and Authority
# 4 1.5 - Public Access
# 5 1.6 - Inquiries
# 6 ‹ Introductory Information
# 7 up
# 8 1.1 - Scope of Part II: The Office of the Chief Immigration Judge ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 2.1 - Representation Generally
# 1 2.2 - Unrepresented Aliens ("Pro se" Appearances)
# 2 2.3 - Attorneys
# 3 2.4 - Accredited Representatives and Recognized Organizations
# 4 2.5 - Law Students and Law Graduates
# 5 2.6 - Paralegals
# 6 2.7 - Immigration Specialists
# 7 2.8 - Family Members
# 8 2.9 - Others
# 9 ‹ 1.6 - Inquiries
# 10 up
# 11 2.1 - Representation Generally ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 3.1 - Delivery and Receipt
# 1 3.2 - Service on the Opposing Party
# 2 3.3 - Documents
# 3  3.4 - Filing Fees
# 4 ‹ 2.9 - Others
# 5 up
# 6 3.1 - Delivery and Receipt ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 5.1 - Who May File
# 1 5.2 - Filing a Motion
# 2 5.3 - Motion Limits
# 3 5.4 - Multiple Motions
# 4 5.5 - Motion Briefs
# 5 5.6 - Transcript Requests
# 6 5.7 - Motions to Reopen
# 7 5.8 - Motions to Reconsider
# 8 5.9 - Motions to Reopen In Absentia Orders
# 9 5.10 - Other Motions
# 10 5.11 - Decisions
# 11 5.12 - Response to Motion
# 12 ‹ 4.22 - Juveniles
# 13 up
# 14 5.1 - Who May File ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 7.1 - Overview
# 1 7.2 - Deportation Proceedings and Exclusion Proceedings
# 2 7.3 - Rescission Proceedings
# 3 7.4 - Limited Proceedings
# 4 7.5 - ABC Settlement
# 5 ‹ 6.6 - Additional Information
# 6 up
# 7 7.1 - Overview ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 8.1 - In General
# 1 8.2 - Automatic Stays
# 2 8.3 - Discretionary Stays
# 3 ‹ 7.5 - ABC Settlement
# 4 up
# 5 8.1 - In General ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 9.1 - Detention
# 1 9.2 - Detained Juveniles
# 2 9.3 - Bond Proceedings
# 3 9.4 - Detention Review
# 4 ‹ 8.3 - Discretionary Stays
# 5 up
# 6 9.1 - Detention ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 10.1 - Practitioner Discipline Generally
# 1 10.2 - Definition of Practitioner and Recognized Organization
# 2 10.3 - Jurisdiction
# 3 10.4 - Conduct
# 4 10.5 - Filing a Complaint
# 5 10.6 - Duty to Report
# 6 10.7 - Disciplinary Proceedings
# 7 10.8 - Notice to Public
# 8 10.9 - Effect on Practitioner's Pending Immigration Cases
# 9 10.10 - Reinstatement
# 10 ‹ 9.4 - Detention Review
# 11 up
# 12 10.1 - Practitioner Discipline Generally ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 11.1 - Forms Generally
# 1 11.2 - Obtaining Blank Forms
# 2 11.3 - Submitting Completed Forms
# 3 11.4 - Additional Information
# 4 ‹ 10.10 - Reinstatement
# 5 up
# 6 11.1 - Forms Generally ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 12.1 - Generally
# 1 12.2 - Requests
# 2 12.3 - Denials
# 3 ‹ 11.4 - Additional Information
# 4 up
# 5 12.1 - Generally ›
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.justice.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 0 ‹ 12.3 - Denials
# 1 up
# 2 Chapter 14 - Local Operating Procedures ›
